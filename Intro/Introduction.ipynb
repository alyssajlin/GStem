# %%
import pandas as pd

# %%
pd.read_csv("data/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df = pd.read_csv("data/surveys.csv")

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
pd.unique(surveys_df['plot_id'])
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
site_names=pd.unique(surveys_df['plot_id'])

# %%
len(site_names)
# Out:
# 24

# %%
surveys_df['plot_id'].nunique()
# Out:
# 24

# %%
grouped_data=surveys_df.groupby('sex')

# %% [raw]
# grouped_data.describe()

# %%
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
grouped_data2=surveys_df.groupby(['plot_id','sex'])

# %%
grouped_data2.describe()
# Out:
#                 day                                                     \
#               count       mean       std  min   25%   50%    75%   max
# plot_id sex
# 1       F     848.0  15.338443  8.325993  1.0   9.0  15.0  22.00  31.0
#         M    1095.0  15.905936  8.053257  1.0   9.0  16.0  23.00  31.0
# 2       F     970.0  16.288660  8.046509  1.0  10.0  16.0  23.00  31.0
#         M    1144.0  15.440559  8.414667  1.0   9.0  15.0  23.00  31.0
# 3       F     893.0  16.161254  7.961706  1.0   9.0  16.0  23.00  31.0
#         M     840.0  16.450000  7.916120  1.0  10.0  16.0  23.00  31.0
# 4       F     872.0  15.746560  8.217829  1.0   9.0  16.0  22.00  31.0
#         M    1030.0  16.507767  8.257837  1.0   9.0  16.0  23.00  31.0
# 5       F     527.0  15.722960  8.465716  1.0   9.0  16.0  23.00  31.0
#         M     586.0  15.703072  8.227776  1.0   9.0  16.0  22.00  31.0
# 6       F     737.0  16.313433  8.297017  1.0   9.0  16.0  23.00  31.0
# ...

# %%
grouped_data2.mean()
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# plot_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.604703  16.161254  1992.013438        23.774044
#         M    20226.767857  6.271429  16.450000  1992.275000        23.833744
# 4       F    17489.205275  6.442661  15.746560  1990.235092        33.249102
#         M    18493.841748  6.430097  16.507767  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.628223  16.313433  1991.579376        26.981322
# ...

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.head
# Out:
# <bound method NDFrame.head of        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
 group=surveys_df.groupby(['plot_id'])

# %%
group

# %%
grouped_data2 = surveys_df.groupby(['plot_id','sex'])

# %%
group['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
# %matplotlib inline

# %%
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
total_count.plot(kind='bar');

# %%
average_weight=surveys_df.groupby('species_id')['weight'].mean()
average_weight.plot(kind='bar');

# %%
bygender=surveys_df.groupby('sex')['record_id'].count()
bygender.plot(kind='bar')

# %%
by_site_sex=surveys_df.groupby(['plot_id','sex']).weight.sum()
by_site_sex
# Out:
# plot_id  sex
# 1        F      38253.0
#          M      59979.0
# 2        F      50144.0
#          M      57250.0
# 3        F      27251.0
#          M      28253.0
# 4        F      39796.0
#          M      49377.0
# 5        F      21143.0
#          M      23326.0
# 6        F      26210.0
#          M      27245.0
# 7        F       6522.0
#          M       6422.0
# 8        F      37274.0
#          M      47755.0
# 9        F      44128.0
#          M      48727.0
# 10       F       2359.0
#          M       2776.0
# 11       F      34638.0
#          M      43106.0
# 12       F      51825.0
#          M      57420.0
# 13       F      24720.0
#          M      30354.0
# 14       F      32770.0
#          M      46469.0
# 15       F      12455.0
#          M      11037.0
# 16       F       5446.0
#          M       6310.0
# 17       F      42106.0
#          M      48082.0
# 18       F      27353.0
#          M      26433.0
# 19       F      11297.0
# ...

# %%
by_site_sex.unstack()
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %%
by_site_sex = surveys_df.groupby(['plot_id','sex'])
site_sex_count = by_site_sex['weight'].sum()
spc = site_sex_count.unstack()
spc
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %%
s_plot = spc.plot(kind='bar',stacked=True,title="Total weight by site and sex")

# %%
#Indexing, Slicing and Subsetting DataFrames in Python

# %%
import pandas as pd
surveys_df = pd.read_csv("data/surveys.csv")
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
# 5         PF
# 6         PE
# 7         DM
# 8         DM
# 9         PF
# 10        DS
# 11        DM
# 12        DM
# 13        DM
# 14        DM
# 15        DM
# 16        DS
# 17        PP
# 18        PF
# 19        DS
# 20        DM
# 21        NL
# 22        DM
# 23        SH
# 24        DM
# 25        DM
# 26        DM
# 27        DM
# 28        PP
# 29        DS
#         ...
# 35519     SF
# 35520     DM
# 35521     DM
# 35522     DM
# 35523     PB
# 35524     OL
# 35525     OT
# 35526     DO
# 35527     US
# 35528     PB
# 35529     OT
# 35530     PB
# 35531     DM
# 35532     DM
# 35533     DM
# 35534     DM
# 35535     DM
# 35536     DM
# 35537     PB
# 35538     SF
# 35539     PB
# 35540     PB
# 35541     PB
# 35542     PB
# 35543     US
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
surveys_species=surveys_df['species_id']
surveys_species
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
# 5         PF
# 6         PE
# 7         DM
# 8         DM
# 9         PF
# 10        DS
# 11        DM
# 12        DM
# 13        DM
# 14        DM
# 15        DM
# 16        DS
# 17        PP
# 18        PF
# 19        DS
# 20        DM
# 21        NL
# 22        DM
# 23        SH
# 24        DM
# 25        DM
# 26        DM
# 27        DM
# 28        PP
# 29        DS
#         ...
# 35519     SF
# 35520     DM
# 35521     DM
# 35522     DM
# 35523     PB
# 35524     OL
# 35525     OT
# 35526     DO
# 35527     US
# 35528     PB
# 35529     OT
# 35530     PB
# 35531     DM
# 35532     DM
# 35533     DM
# 35534     DM
# 35535     DM
# 35536     DM
# 35537     PB
# 35538     SF
# 35539     PB
# 35540     PB
# 35541     PB
# 35542     PB
# 35543     US
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
surveys_df[['species_id', 'plot_id']]
# Out:
#       species_id  plot_id
# 0             NL        2
# 1             NL        3
# 2             DM        2
# 3             DM        7
# 4             DM        3
# 5             PF        1
# 6             PE        2
# 7             DM        1
# 8             DM        1
# 9             PF        6
# 10            DS        5
# 11            DM        7
# 12            DM        3
# 13            DM        8
# 14            DM        6
# 15            DM        4
# 16            DS        3
# 17            PP        2
# 18            PF        4
# 19            DS       11
# 20            DM       14
# 21            NL       15
# 22            DM       13
# 23            SH       13
# 24            DM        9
# 25            DM       15
# 26            DM       15
# 27            DM       11
# 28            PP       11
# 29            DS       10
# ...          ...      ...
# 35519         SF        9
# 35520         DM        9
# 35521         DM        9
# ...

# %%
surveys_df[['plot_id', 'species_id']]
# Out:
#        plot_id species_id
# 0            2         NL
# 1            3         NL
# 2            2         DM
# 3            7         DM
# 4            3         DM
# 5            1         PF
# 6            2         PE
# 7            1         DM
# 8            1         DM
# 9            6         PF
# 10           5         DS
# 11           7         DM
# 12           3         DM
# 13           8         DM
# 14           6         DM
# 15           4         DM
# 16           3         DS
# 17           2         PP
# 18           4         PF
# 19          11         DS
# 20          14         DM
# 21          15         NL
# 22          13         DM
# 23          13         SH
# 24           9         DM
# 25          15         DM
# 26          15         DM
# 27          11         DM
# 28          11         PP
# 29          10         DS
# ...        ...        ...
# 35519        9         SF
# 35520        9         DM
# 35521        9         DM
# ...

# %%
a = [1, 2, 3, 4, 5]
a[0]
# Out:
# 1

# %%
a[len(a)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-836f840eaf9f> in <module>()
# ----> 1 a[len(a)]
#
# IndexError: list index out of range

# %%
surveys_df.iloc[0:3, 1:4]

# %%
surveys_df.loc[[0, 10], :]

# %%
surveys_df[(surveys_df.year==1999)&(surveys_df.weight<=8)]

# %%
surveys_df[surveys_df['species_id'].isin(['NL'])]

# %%
surveys_df[surveys_df.weight>=0]

# %%
surveys_df[~surveys_df.sex.isin(['M'])]

# %%
pd.isnull(surveys_df)

# %%
surveys_df[pd.isnull(surveys_df).any(axis=1)]

# %%
empty_weights = surveys_df[pd.isnull(surveys_df['weight'])]['weight']
print(empty_weights)

# %%
#Create a new DataFrame that only contains observations with sex values that are not female or male. 
#Assign each sex value in the new DataFrame to a new value of ‘x’. 
#Determine the number of null values in the subset.


sex_df=surveys_df[pd.isnull(surveys_df['sex'])]
#sex_df['sex']=sex_df['sex'].fillna('x')
s_df = sex_df.copy()
s_df.loc[:,'sex']='x'
print(s_df)
len(sex_df[pd.isnull(sex_df).any(axis=1)])

# %%
#Create a new DataFrame that contains only observations that are of sex male or female and where weight values are 
#greater than 0. Create a stacked bar plot of average weight by plot with male vs female values stacked for each 
#plot.
new_df=surveys_df[(surveys_df.sex=='M')|(surveys_df.sex=='F')&(surveys_df.weight>0)]
new_dfs=new_df.groupby(['plot_id','sex'])
new_dfw=new_dfs['weight'].mean().unstack()
new_dfw.plot(kind='bar', stacked=True, title="Average weight by sex and plot")

# %%
#Data Types and Formats

# %%
import pandas as pd
surveys_df = pd.read_csv("data/surveys.csv")
surveys_df

# %%
surveys_df['sex'].dtype

# %%
surveys_df['record_id'].dtype

# %%
surveys_df.dtypes

# %%
surveys_df.plot_id.astype("float")

# %%
#surveys_df.weight.astype("int")

# %%
df1 = surveys_df.copy()
df1['weight'] = df1['weight'].fillna(0)
df1['weight'].mean()
df1['weight'] = surveys_df['weight'].fillna(surveys_df['weight'].mean())
len(df1[pd.isnull(df1).any(axis=1)])

#Count the number of missing values per column. Hint: The method .count() gives you the number of non-NA observations per column. Try looking to the .isnull() method.

# %%
surveys_df = pd.read_csv("data/surveys.csv")
df_na = surveys_df.dropna()
df_na

# %%
df_na.to_csv('data/surveys_complete.csv', index=False)
pd.read_csv('data/surveys_complete.csv')

# %%
#Combining DataFrames with Pandas

surveys_df = pd.read_csv("data/surveys.csv",
                         keep_default_na=False, na_values=[""])
surveys_df

# %%
survey_sub = surveys_df.head(10)
print (survey_sub)

# %%
survey_sub_last10 = surveys_df.tail(10)
survey_sub_last10=survey_sub_last10.reset_index(drop=True)
print (survey_sub_last10)

# %%
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)
print (vertical_stack)

# %%
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1).reset_index() 
print (horizontal_stack)

# %%
vertical_stack.reset_index()

# %%
vertical_stack.to_csv('data/out.csv', index=False)

# %%
new_output = pd.read_csv('data/out.csv', keep_default_na=False, na_values=[""])
new_output

# %%
pd.read_csv("data/survey2001.csv")
s2001=pd.read_csv("data/survey2001.csv")
pd.read_csv("data/survey2002.csv")
s2002=pd.read_csv("data/survey2002.csv")

# %%
combineds=pd.concat([s2001,s2002], axis=0, sort=True)
combineds

# %%
combineds=pd.concat([s2001,s2002], axis=0, sort=True)
combineds=combineds.groupby(['sex', 'year']).wgt.mean().unstack()
combineds.plot(kind="bar")

# %%
combineds.to_csv("weight_for_year.csv")
pd.read_csv("weight_for_year.csv", index_col=0)

# %%
survey_sub = surveys_df.head(10)
species_sub = pd.read_csv('data/speciesSubset.csv', keep_default_na=False, na_values=[""])
species_sub

# %%
species_sub.columns

# %%
survey_sub.columns

# %%
merged_inner = pd.merge(left=survey_sub,right=species_sub, left_on='species_id', right_on='species_id')
merged_inner.shape

# %%
merged_inner

# %%
merged_left = pd.merge(left=survey_sub,right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_left.shape

merged_left

# %%
merged_right=pd.merge(left=survey_sub, right=species_sub, how='right',left_on='species_id',right_on='species_id')
merged_right

# %%
pd.read_csv("data/species.csv")
species_df=pd.read_csv("data/species.csv")
combined=pd.merge(left=surveys_df,right=species_df,how='left',left_on='species_id',right_on='species_id')
combined
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
combined_plot=combined.groupby(['plot_id']).taxa.nunique()
combined_plot.plot(kind="bar")

# %%
tsp=combined.groupby(['plot_id','sex']).taxa.nunique().unstack()
tsp.plot(kind="bar", stacked=True)

# %%
#Data Workflows and Automation
animals = ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']
print(animals)
# Out:
# ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']

# %%
for creature in animals:
    print(creature)
# Out:
# lion
# tiger
# crocodile
# vulture
# hippo

# %%
for creature in animals:
    pass
print('The loop variable is now: ' + creature)
# Out:
# The loop variable is now: hippo

# %%
string=""
for creature in animals:
    string=string+creature+', '
print (string)
# Out:
# lion, tiger, crocodile, vulture, hippo,

# %%
import os

os.listdir('data')
# Out:
# ['speciesSubset.csv',
#  'Portal_rodents_19772002_scinameUUIDs.csv',
#  'bouldercreek_09_2013.txt',
#  'species.csv',
#  '.gitkeep',
#  'yearly_files',
#  'surveys.csv',
#  'out.csv',
#  'portal_mammals.sqlite',
#  'surveys_complete.csv',
#  'survey2001.csv',
#  'plots.csv',
#  'survey2002.csv']

# %%
import pandas as pd

# Load the data into a DataFrame
surveys_df = pd.read_csv('data/surveys.csv')

# Select only data for the year 2002
surveys2002 = surveys_df[surveys_df.year == 2002]

# Write the new DataFrame to a CSV file
surveys2002.to_csv('data/yearly_files/surveys2002.csv')

# %%
surveys_df['year'].unique()
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002])

# %%
for year in surveys_df['year'].unique():
   filename='data/yearly_files/surveys' + str(year) + '.csv'
   print(filename)
# Out:
# data/yearly_files/surveys1977.csv
# data/yearly_files/surveys1978.csv
# data/yearly_files/surveys1979.csv
# data/yearly_files/surveys1980.csv
# data/yearly_files/surveys1981.csv
# data/yearly_files/surveys1982.csv
# data/yearly_files/surveys1983.csv
# data/yearly_files/surveys1984.csv
# data/yearly_files/surveys1985.csv
# data/yearly_files/surveys1986.csv
# data/yearly_files/surveys1987.csv
# data/yearly_files/surveys1988.csv
# data/yearly_files/surveys1989.csv
# data/yearly_files/surveys1990.csv
# data/yearly_files/surveys1991.csv
# data/yearly_files/surveys1992.csv
# data/yearly_files/surveys1993.csv
# data/yearly_files/surveys1994.csv
# data/yearly_files/surveys1995.csv
# data/yearly_files/surveys1996.csv
# data/yearly_files/surveys1997.csv
# data/yearly_files/surveys1998.csv
# data/yearly_files/surveys1999.csv
# data/yearly_files/surveys2000.csv
# data/yearly_files/surveys2001.csv
# data/yearly_files/surveys2002.csv

# %%
for year in surveys_df['year'].unique():

    # Select data for the year
    surveys_year = surveys_df[surveys_df.year == year]

    # Write the new DataFrame to a CSV file
    filename = 'data/yearly_files/surveys' + str(year) + '.csv'
    surveys_year.to_csv(filename)

# %%
os.listdir('data/yearly_files')
# Out:
# ['surveys2001.csv',
#  'surveys2000.csv',
#  'surveys2002.csv',
#  'surveys1999.csv',
#  'function_surveys1993.csv',
#  'function_surveys1987.csv',
#  'function_surveys1978.csv',
#  'function_surveys1979.csv',
#  'function_surveys1986.csv',
#  'function_surveys1992.csv',
#  'surveys1998.csv',
#  'function_surveys1984.csv',
#  'function_surveys1990.csv',
#  'function_surveys1991.csv',
#  'function_surveys1985.csv',
#  'function_surveys1981.csv',
#  'function_surveys1995.csv',
#  'function_surveys1994.csv',
#  'function_surveys1980.csv',
#  'surveys1988.csv',
#  'surveys1977.csv',
#  'function_surveys1996.csv',
#  'function_surveys1982.csv',
#  'function_surveys1983.csv',
#  'function_surveys1997.csv',
#  'surveys1989.csv',
#  'surveys1990.csv',
#  'surveys1984.csv',
#  'surveys1985.csv',
#  'surveys1991.csv',
#  'surveys1987.csv',
#  'surveys1993.csv',
#  'surveys1978.csv',
#  'function_surveys1999.csv',
#  'function_surveys1998.csv',
#  'surveys1979.csv',
#  'surveys1992.csv',
# ...

# %%
for year in surveys_df['year'].unique():
    surveys_year = surveys_df[surveys_df.year == year].dropna()

# %%
#How would you modify your loop in order to generate a data file for only every 5th year, starting from 1977?
n=5
for year in range (surveys_df['year'].unique().min(), surveys_df['year'].unique().max(), n):
    filename = 'data/yearly_files/surveys' + str(year) + '.csv'
    print (filename)
# Out:
# data/yearly_files/surveys1977.csv
# data/yearly_files/surveys1982.csv
# data/yearly_files/surveys1987.csv
# data/yearly_files/surveys1992.csv
# data/yearly_files/surveys1997.csv

# %%
#Instead of splitting out the data by years, a colleague wants to do analyses each species separately.
#How would you write a unique CSV file for each species?

for species in (surveys_df['species_id']).unique():
    filename = 'data/yearly_files/surveys' + str(species) + '.csv'
