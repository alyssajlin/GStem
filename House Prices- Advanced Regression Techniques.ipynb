# %%
import pandas as pd
# %matplotlib inline
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

data=pd.read_csv("train.csv", index_col=0)
data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal     208500
# 2          NaN       0      5    2007        WD         Normal     181500
# 3          NaN       0      9    2008        WD         Normal     223500
# 4          NaN       0      2    2006        WD        Abnorml     140000
# 5          NaN       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
data[['SalePrice','1stFlrSF']]
#data.plot(x='LotFrontage', y='SalePrice', kind='scatter')
#sns.regplot(data['LotFrontage'], data['SalePrice'])
"""x = data[["1stFlrSF"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("First Floor Square Footage")
ax.set_ylabel("Selling Price")"""
# Out:
# 'x = data[["1stFlrSF"]]\ny = data[[\'SalePrice\']]\n\nx_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)\n\nregr = linear_model.LinearRegression()\nregr.fit(x_train, y_train)\nprint(\'Coefficients: \n\', regr.coef_)\nprint("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))\n#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))\n#print(\'R^2: %.2f\' % regr.score(x_train, y_train))\n\nax = plt.subplot(111)\nplt.scatter(x_validation, y_validation, color = \'black\')\nplt.plot(x_validation, regr.predict(x_validation), color = \'red\', linewidth = 3)\nax.set_xlabel("First Floor Square Footage")\nax.set_ylabel("Selling Price")'

# %%
#sns.regplot(data['YearBuilt'], data['SalePrice'])

# %%
sns.regplot(data['TotalBsmtSF'], data['SalePrice'])

# %%
x = data[["TotalBsmtSF"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("Total basement area in square feet")
ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[100.43491218]]
# Root Mean squared error (RMSE): 65679.67
# Text(0,0.5,'Selling Price')

# %%
sns.regplot(data['1stFlrSF'], data['SalePrice'])

# %%
x = data[["1stFlrSF"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("First floor surface area in square feet")
ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[113.99204906]]
# Root Mean squared error (RMSE): 66128.35
# Text(0,0.5,'Selling Price')

# %%
sns.regplot(data['GarageYrBlt'], data['SalePrice'])

# %%
sns.regplot(data['GarageCars'], data['SalePrice'])

# %%
x = data[["GarageCars"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("Size of garage in car capacity")
ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[67062.94855072]]
# Root Mean squared error (RMSE): 66406.48
# Text(0,0.5,'Selling Price')

# %%
sns.regplot(data['GarageArea'], data['SalePrice'])

# %%
x = data[["GarageArea"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("Garage Area")
ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[226.93274858]]
# Root Mean squared error (RMSE): 67299.54
# Text(0,0.5,'Selling Price')

# %%
sns.regplot(data['GrLivArea'], data['SalePrice'])

# %%
x = data[["GrLivArea"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("Above ground living area square feet")
ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[98.50395317]]
# Root Mean squared error (RMSE): 56577.61
# Text(0,0.5,'Selling Price')

# %%
sns.regplot(data['OverallQual'], data['SalePrice'])

# %%
x = data[["OverallQual"]]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

ax = plt.subplot(111)
plt.scatter(x_validation, y_validation, color = 'black')
plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
ax.set_xlabel("Overall Quality")
ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[43696.47641718]]
# Root Mean squared error (RMSE): 51746.72
# Text(0,0.5,'Selling Price')

# %%
#sns.regplot(data['EnclosedPorch'], data['SalePrice'])
#sns.regplot(data['3SsnPorch'], data['SalePrice'])
#sns.regplot(data['PoolArea'], data['SalePrice'])
#sns.regplot(data['MoSold'], data['SalePrice'])
#sns.regplot(data['YrSold'], data['SalePrice'])
#sns.regplot(data['BsmtFullBath'], data['SalePrice'])
#sns.regplot(data['BsmtHalfBath'], data['SalePrice'])
#sns.regplot(data['FullBath'], data['SalePrice'])
#sns.regplot(data['HalfBath'], data['SalePrice'])
#sns.regplot(data['Fireplaces'], data['SalePrice'])
#sns.regplot(data['BsmtFinSF2'], data['SalePrice'])
#sns.regplot(data['BsmtUnfSF'], data['SalePrice'])
#sns.regplot(data['LotArea'], data['SalePrice'])
#sns.regplot(data['WoodDeckSF'], data['SalePrice'])
#sns.regplot(data['OpenPorchSF'], data['SalePrice'])
#sns.regplot(data['ScreenPorch'], data['SalePrice'])
#sns.regplot(data['2ndFlrSF'], data['SalePrice'])
#sns.regplot(data['YearRemodAdd'],data['SalePrice'])
#sns.regplot(data['BsmtFinSF1'],data['SalePrice'])

# %%
numericlist=data.select_dtypes(include='int64').drop('SalePrice',axis=1)


x = numericlist[['GrLivArea','OverallQual','GarageArea', 'GarageCars', 'TotalBsmtSF']]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

#ax = plt.subplot(111)
#plt.scatter(x_validation, y_validation, color = 'black')
#plt.plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
#ax.set_xlabel("Overall Quality")
#ax.set_ylabel("Selling Price")
# Out:
# Coefficients:
#  [[3.81057440e+01 2.41930661e+04 1.29996396e+01 1.80906483e+04
#   2.47581938e+01]]
# Root Mean squared error (RMSE): 39743.63

# %%
import seaborn as sns

def reg_plots(df, target):
    columns = data.select_dtypes(include=['number']).drop(target, axis= 1).columns
    col_num = len(columns)//3
    fig, axarr = plt.subplots( col_num,3, figsize=(18, 50))
    axarr = axarr.flatten()
    for i in range(len(columns)):
        sns.regplot(df[columns[i]], df[target], ax=axarr[i])

# %%
reg_plots(data, 'SalePrice')

# %%
from sklearn.metrics import mean_squared_error as mse

def linear_regression(df, target):
    columns = df.select_dtypes(include=['int64']).drop(target, axis= 1).columns
    for j, i in enumerate(columns):
        # Set x and y axes 
        X = df[[i]]
        Y = df[[target]]
        # Split the data 
        x_train, x_validation, y_train, y_validation = train_test_split(X,Y,\
                                                                        test_size = 0.33, random_state = 42)
        # Fitting model for training set
        regr = linear_model.LinearRegression()
        regr.fit(x_train, y_train)
        # predicting the target
        train_prediction = regr.predict(x_validation)
        
        #calculating the error (check if it matches with the other caculation you guys were using )
        RMSE = round(mse(y_validation, train_prediction)**0.5, 2)
        if RMSE<70000:
            print(i, RMSE, round(regr.coef_[0][0]))

# %%
linear_regression(data, 'SalePrice')
# Out:
# OverallQual 51746.72 43696.0
# TotalBsmtSF 65679.67 100.0
# 1stFlrSF 66128.35 114.0
# GrLivArea 56577.61 99.0
# FullBath 69301.45 75603.0
# GarageCars 66406.48 67063.0
# GarageArea 67299.54 227.0

# %%
# Combination of both functions


def linear_regressionp(df, target):
    columns = df.select_dtypes(include=['int64']).drop(target, axis= 1).columns
    col_num = len(columns)//3
    fig, axarr = plt.subplots( col_num,3, figsize=(18, 50))
    axarr = axarr.flatten()
    for j, i in enumerate(columns):
        # Set x and y axes 
        X = df[[i]]
        Y = df[[target]]
        # Split the data 
        x_train, x_validation, y_train, y_validation = train_test_split(X,Y,\
                                                                        test_size = 0.33, random_state = 42)
        # Fitting model for training set
        regr = linear_model.LinearRegression()
        regr.fit(x_train, y_train)
        train_prediction = regr.predict(x_validation)
        RMSE = round(mse(y_validation, train_prediction)**0.5, 2)
        if RMSE<66000:
            axarr[j].scatter(x_validation, y_validation, color = 'black')
            axarr[j].plot(x_validation, regr.predict(x_validation), color = 'red', linewidth = 3)
            axarr[j].set_xlabel(i)
            axarr[j].set_ylabel(target)
            axarr[j].text(0.2,0.8,"RMSE: "+ str(RMSE)+'\nCoefficients: '+str(round(regr.coef_[0][0])),\
                     transform=axarr[j].transAxes)

# %%
linear_regressionp(data, 'SalePrice')

# %%
data_=data[['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'GarageCars', 'GarageArea','SalePrice']]

# %%
x = data_.drop('SalePrice',axis=1)
y = data_[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
#print("Mean squared error (RMSE): %.2f" % np.sqrt(mean_squared_error(y_validation,regr.predict(x_validation))))
#print('R^2: %.2f' % regr.score(x_train, y_train))

#all RMSE under 70000, more precise than all data
# Out:
# Coefficients:
#  [[2.43642011e+04 1.54668181e+01 1.48852681e+01 3.36500306e+01
#   3.39896304e+03 1.72753212e+04 1.30299728e+01]]
# Root Mean squared error (RMSE): 39847.20

# %%
numericlist=data.select_dtypes(include='int64').drop('SalePrice',axis=1)

x = numericlist #all numerical data
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
# Out:
# Coefficients:
#  [[-1.89643267e+02  4.44184537e-01  1.88346578e+04  2.57104746e+03
#    3.04866038e+02  2.00263625e+02  8.22405098e+00 -5.32677687e+00
#   -7.48802534e-01  2.14847158e+00  5.00241445e+00  2.12317834e+00
#    2.61949034e+01  3.33204962e+01  1.17025698e+04  8.53564215e+02
#    5.53042960e+03  3.42789352e+02 -9.91718519e+03 -1.11625663e+04
#    6.88965298e+03  4.85557582e+03  1.20438394e+04  4.13721311e+00
#    2.95824758e+01 -1.19117287e+01  1.18417926e+01  4.91685105e+01
#    9.19640196e+01 -1.65335304e+02 -1.46567276e+00 -9.87825865e+01
#   -1.05147165e+02]]
# Root Mean squared error (RMSE): 40129.81

# %%
numericlist=data.select_dtypes(include='int64').drop('SalePrice',axis=1)


x = numericlist[['GrLivArea','OverallQual','GarageArea', 'GarageCars', 'TotalBsmtSF']]
y = data[['SalePrice']]

x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size = 0.33, random_state = 42)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Coefficients: \n', regr.coef_)
print("Root Mean squared error (RMSE): %.2f" % np.sqrt(np.mean((regr.predict(x_validation) - y_validation) ** 2)))
# Out:
# Coefficients:
#  [[3.81057440e+01 2.41930661e+04 1.29996396e+01 1.80906483e+04
#   2.47581938e+01]]
# Root Mean squared error (RMSE): 39743.63
